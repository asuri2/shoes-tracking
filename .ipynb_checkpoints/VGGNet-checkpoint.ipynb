# %%
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
import numpy as np

from scipy.spatial import distance
from keras.models import Model
from keras.applications import resnet50
# Out:
# Using TensorFlow backend.

# %%
model = VGG16(weights='imagenet', include_top=True)
# model.summary()
img_path = "G:\\Download\\ut-zap50k-images-square\\ut-zap50k-images-square\\Sandals\\Athletic\\Keen\\7596238.3.jpg"
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# the image is now in an array of shape (3, 224, 224) 
# need to expand it to (1, 3, 224, 224) as it's expecting a list
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
prediction = model.predict(x)
print(prediction[0].shape)
label = decode_predictions(prediction)
print(label)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-f2f588d31b0f> in <module>()
# ----> 1 model = VGG16(weights='imagenet', include_top=True)
#       2 # model.summary()
#       3 img_path = "G:\\Download\\ut-zap50k-images-square\\ut-zap50k-images-square\\Sandals\\Athletic\\Keen\\7596238.3.jpg"
#       4 img = image.load_img(img_path, target_size=(224, 224))
#       5 x = image.img_to_array(img)
#
# ~\AppData\Local\conda\conda\envs\carnd-term1\lib\site-packages\keras_applications\vgg16.py in VGG16(include_top, weights, input_tensor, input_shape, pooling, classes)
#     182         x = layers.Dense(4096, activation='relu', name='fc1')(x)
#     183         x = layers.Dense(4096, activation='relu', name='fc2')(x)
# --> 184         x = layers.Dense(classes, activation='softmax', name='predictions')(x)
#     185     else:
#     186         if pooling == 'avg':
#
# ...

# %%
from keras.models import Model

model = VGG16(weights='imagenet', include_top=True)
model_extractfeatures = Model(input=model.input, output=model.get_layer('fc2').output)
fc2_features = model_extractfeatures.predict(x)
print(fc2_features.shape)
# Out:
# C:\Users\Abhishek\Anaconda3\envs\carnd-term1\lib\site-packages\ipykernel\__main__.py:2: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("fc...)`
#   from ipykernel import kernelapp as app
# (1, 4096)

# %%
from keras import applications
model = applications.resnet50.ResNet50(weights='imagenet', include_top=True, pooling='avg')
# Out:
# ...
# 94658560/94653016 [==============================] - 409s 4us/step

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_8 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_8[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# ...

# %%
from keras import applications
model = applications.resnet50.ResNet50(weights='imagenet', include_top=True, pooling='avg')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_17 (InputLayer)           (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_17[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 112, 112, 64) 0           bn_conv1[0][0]
# ...

# %%
from keras.applications.resnet50 import decode_predictions
import cv2

img_path = "C:\\Users\\Abhishek\\Desktop\\ChatBot\\poc\\ut-zap50k-images-square\\Sandals\\Athletic\\Keen\\7596238.3.jpg"
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# img = cv2.imread(img_path)
# x = cv2.resize(img,(224,224))
# print(img.shape)
# # x = np.transpose(img, (2, 0, 1))
# print(x.shape)
# the image is now in an array of shape (3, 224, 224) 
# need to expand it to (1, 3, 224, 224) as it's expecting a list
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
prediction = model.predict(x)
print(prediction[0].shape)
label = decode_predictions(prediction)
print(label)
# Out:
# (1000,)
# [[('n04133789', 'sandal', 0.87964743), ('n03047690', 'clog', 0.037014622), ('n03794056', 'mousetrap', 0.018968536), ('n04120489', 'running_shoe', 0.011514999), ('n03954731', 'plane', 0.010139309)]]

# %%
from scipy.spatial import distance
dst_euc = []
dst_cos = []
distance.euclidean(a, b)
