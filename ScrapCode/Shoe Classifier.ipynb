# %%
import sys, os, glob
import cv2
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
root = 'G:\\Download\\ut-zap50k-images-square\\ut-zap50k-images-square'
data = []
os.chdir(root)
print("In:",os.getcwd())
for dirs1 in os.listdir(root):
    path1 = root + "\\" + dirs1
    for dirs2 in os.listdir(path1):
        path2 = path1 + "\\" + dirs2
        for dirs3 in os.listdir(path2):
            path3 = path2 + "\\" + dirs3
            for jpg in os.listdir(path3):                
                path4 = path3 + "\\" + jpg
                img = cv2.imread(path4)
                if img is not None:
                    data.append(img)
# Out:
# In: G:\Download\ut-zap50k-images-square\ut-zap50k-images-square
# 50062

# %%
print(len(data))
# Out:
# 50062

# %%
print(data[0].shape)
# Out:
# (136, 136, 3)

# %%
plt.imshow(data[11484])

# %%
# Saving images in pickle file
outfile = open("C:\\Users\\Akhil Suri\\Documents\\Udacity\\shoes.sav", 'wb')
pickle.dump(data, outfile)
outfile.close()
